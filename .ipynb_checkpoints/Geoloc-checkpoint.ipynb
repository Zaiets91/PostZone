# %%
import matplotlib
import matplotlib.path as mplPath
import numpy as np
import matplotlib.pyplot as plt
import gmplot
import itertools
from IPython.core.display import display
from IPython.lib.display import IFrame
import os
import copy
import urllib, json
# %matplotlib inline

# %%
class PostMatcher(object):
    def __init__(self, points, all_postals = [], time = 9000):
        if not type(points) is list or not type(points[0]) is dict:
            # [float] in case we will change from 1 point to set of points
            print "points should be a list of objects: [{postal: *postalcode*, x: *[float]*, y: *[float]*}]"
            raise Exception(points)
        self.points = points
        self.all_postals = all_postals
        self.time_space = []
        self.time = time
        
    def to_array(self, arr):
        x, y = [], []
        for i in arr:
            d = i.split(',')
            x.append(float(d[0]))
            y.append(float(d[1]))
        return x, y
            
    # thx and soz http://www.flаvіоgоrtаnа.com/isоscоpe/ - don't copy it, there're cyryllic letters
    def getSpace(self, postal, x, y, time): # time in seconds               
        #response = urllib.urlopen(url)
        #data = json.loads(response.read())
        arr = ["60.46875,5.4959106","60.46875,5.559082","60.4742432,5.5755615","60.4852295,5.5865479","60.4962158,5.6195068","60.5126953,5.625","60.534668,5.625","60.5511475,5.6304932","60.5950928,5.6744385","60.6060791,5.7073975","60.6170654,5.7073975","60.6280518,5.6744385","60.6610107,5.6414795","60.6719971,5.6085205","60.6884766,5.6030273","60.7104492,5.6030273","60.7269287,5.6085205","60.737915,5.6414795","60.7489014,5.6524658","60.7543945,5.6689453","60.7543945,5.690918","60.7598877,5.7073975","60.770874,5.7183838","60.7763672,5.7348633","60.7763672,5.8666992","60.770874,5.8831787","60.7543945,5.8886719","60.7324219,5.8886719","60.7159424,5.8831787","60.7049561,5.8721924","60.6939697,5.8721924","60.6884766,5.8886719","60.6884766,5.9106445","60.6939697,5.927124","60.7049561,5.9381104","60.7104492,5.9545898","60.7104492,5.9985352","60.7159424,6.0150146","60.7269287,6.0150146","60.737915,5.9820557","60.7598877,5.960083","60.7763672,5.9545898","60.7983398,5.9545898","60.8148193,5.960083","60.8258057,5.993042","60.836792,6.0040283","60.8422852,6.0205078","60.8422852,6.0864258","60.8477783,6.1029053","60.8587646,6.1138916","60.869751,6.1468506","60.8807373,6.1578369","60.8862305,6.1743164","60.8862305,6.2182617","60.8807373,6.2347412","60.869751,6.2457275","60.8587646,6.2786865","60.8422852,6.2841797","60.8203125,6.2841797","60.803833,6.2786865","60.7928467,6.2677002","60.7763672,6.262207","60.7598877,6.2677002","60.7489014,6.2786865","60.7324219,6.2841797","60.7159424,6.2786865","60.7049561,6.2677002","60.6939697,6.2677002","60.6884766,6.2841797","60.6884766,6.3061523","60.6829834,6.3226318","60.6719971,6.3336182","60.6719971,6.3446045","60.7159424,6.3885498","60.7324219,6.394043","60.7763672,6.394043","60.7928467,6.3885498","60.803833,6.3775635","60.8203125,6.3720703","60.8642578,6.3720703","60.8807373,6.3665771","60.90271,6.3446045","60.9136963,6.3116455","60.9356689,6.2896729","60.9521484,6.2841797","60.9686279,6.2896729","60.9796143,6.3006592","60.9960938,6.3061523","61.0180664,6.3061523","61.0345459,6.3116455","61.0675049,6.3446045","61.1004639,6.3555908","61.1114502,6.3885498","61.1224365,6.3995361","61.1279297,6.4160156","61.1279297,6.4599609","61.1334229,
500977","60.5566406,6.3061523","60.5511475,6.2896729","60.5181885,6.2567139","60.5126953,6.2402344","60.5126953,6.2182617","60.5072021,6.2017822","60.4962158,6.1907959","60.4852295,6.1578369","60.4742432,6.1468506","60.46875,6.1303711","60.46875,6.0424805","60.4742432,6.026001","60.4852295,6.0150146","60.4962158,5.9820557","60.5072021,5.9710693","60.5126953,5.9545898","60.5126953,5.9106445","60.5181885,5.894165","60.5291748,5.8831787","60.534668,5.8666992","60.534668,5.8447266","60.5291748,5.8282471","60.5126953,5.8227539","60.4962158,5.8282471","60.4852295,5.8392334","60.46875,5.8447266","60.4522705,5.8392334","60.4302979,5.8172607","60.4193115,5.7843018","60.3424072,5.7073975","60.3369141,5.690918","60.3369141,5.625","60.3424072,5.6085205","60.3753662,5.5755615","60.3808594,5.559082","60.3808594,5.4931641","60.3863525,5.4766846","60.402832,5.4711914","60.4467773,5.4711914","60.4632568,5.473938","60.46875,5.4821777","60.46875,5.4959106"]
        lat, lon = self.to_array(arr)
        return {'postal': postal, 'x': x, 'y': y, 'dest_lat': lat, 'dest_lon': lon}
    
    
    #Getting checking location
    def check_location(postcode):
        add1 = "http://maps.googleapis.com/maps/api/geocode/json?components=country:NO%7Cpostal_code:"
        add2 = "&sensor=false"
        url = add1 + postcode + add2
        response = urllib.urlopen(url)
        data = json.loads(response.read())
        latitudes =  data['results'][0]["geometry"]["location"]["lat"]
        longitudes =  data['results'][0]["geometry"]["location"]["lng"]
        return latitudes, longitudes
                
    # checking whether there's collision
    # element: {postal: string, dest_lat: [float], dest_lon: [float]}
    # check_with: [{postal: string, x: float, y: float}]
    def check_collision(self, element, check_with):
        result = {'postal': element['postal'], 'intersects': [], 'nonintersect': []}
        # getting our path Area
        path_data = []
        path_data.append((mplPath.Path.MOVETO, (element['dest_lat'][0], element['dest_lon'][1])))
        for x, y in itertools.izip(element['dest_lat'][1:], element['dest_lon'][1:]):
            path_data.append((mplPath.Path.LINETO, (x, y)))
        # closing our rectangle
        path_data.append((mplPath.Path.LINETO, (element['dest_lat'][0], element['dest_lon'][0])))
        # formating it for matplotlib.Path
        codes, verts = zip(*path_data)
        path = mplPath.Path(verts, codes)
        # checking intersections
        for i, val in enumerate(check_with):
            if path.contains_point((val['x'], val['y'])):
                # should add check for dublicates
                result['intersects'].append(val)
            else:
                result['nonintersect'].append(val)
                
        return result
        
    
    def draw(self, element, markers = [], **kwargs):
        fileName = kwargs.get('fileName',"map.html")
        zoomLevel = kwargs.get('zoomLevel', 7)
        
        x = sum(element['dest_lat'])/len(element['dest_lat'])
        y = sum(element['dest_lon'])/len(element['dest_lon'])
    
        gmap = gmplot.GoogleMapPlotter(x, y, zoomLevel)
        # drawing main area
        gmap.polygon(element['dest_lat'], element['dest_lon'], 'cornflowerblue', edge_width=3)
        # drawing needed markers
        for i in markers:
            print i
            gmap.marker(i['x'], i['y'], title=i['postal'])
        gmap.draw(fileName)
        # проблема в правах доступа и маркер не подтягивает(он находится в папке с библиотекой, а Chrome не дает к нему доступ)
        data = []
        with open(fileName, 'r') as f:
            data = f.read().replace("icon: img,", 'icon: "",')
        os.remove(fileName)
        with open(fileName, 'a') as f:
            f.write(data)
        display(IFrame(fileName, height = 500, width = "90%"))


    def renderSingle(self, postal, x, y, time, re_render = False):
        # don't use that func often, plx, or use it only when you're SURE (it's parsing site)
        for i, val in enumerate(self.time_space):
            if val['postal'] == postal:
                if not re_render: 
                    break
                self.time_space[i] = self.getSpace(postal, x, y, time)
                break
            else:
                self.time_space.append(self.getSpace(postal, x, y, time))
                
        if len(self.time_space) == 0:
            self.time_space.append(self.getSpace(postal, x, y, time))
            
        return 0
    
    def renderAll(self, re_render = False): # time = 2.5 hours
        for i in self.points:
            self.renderSingle(i['postal'], i['x'][0], i['y'][0], self.time, re_render)
        return self.time_space

# %%
   def getSpace(self, postal, x, y, time): # time in seconds
        
        url = "https://isoline.route.cit.api.here.com/routing/7.2/calculateisoline.json?app_id=bVQHRXUn6uNHP3B24bdt&app_code=mwkokcyyoCIfExsmQq0qIg&departure=2016-12-19T15:00:00&mode=fastest;car;traffic:enabled&rangetype=time&start=geo!"+ "59.912123" + ","+"10.747292"+"&range="+ "9000"+"&singlecomponent=false&resolution=10&quality=3&requestId=bd96e51c6b1480a41de72bfa04235e87&jsonCallback=callback_bd96e51c6b1480a41de72bfa04235e87&callback=__jp2151"
        
        response = urllib.urlopen(url)
        #data = json.loads(response.read())
        print url
getSpace(0,0,0,0,0)
# Out:
# https://isoline.route.cit.api.here.com/routing/7.2/calculateisoline.json?app_id=bVQHRXUn6uNHP3B24bdt&app_code=mwkokcyyoCIfExsmQq0qIg&departure=2016-12-19T15:00:00&mode=fastest;car;traffic:enabled&rangetype=time&start=geo!59.912123,10.747292&range=9000&singlecomponent=false&resolution=10&quality=3&requestId=bd96e51c6b1480a41de72bfa04235e87&jsonCallback=callback_bd96e51c6b1480a41de72bfa04235e87&callback=__jp2151

# %%
# testing
# нужно бы ещё парсинг добавить и будет гуд


url = "http://maps.googleapis.com/maps/api/geocode/json?components=country:NO%7Cpostal_code:5954&sensor=false"
response = urllib.urlopen(url)
data = json.loads(response.read())

latitudes = data['results'][0]["geometry"]["location"]["lat"]
longitudes = data['results'][0]["geometry"]["location"]["lng"]


points = [{
        'postal' : 'TEST',
        'x' : [latitudes],
        'y' : [longitudes]
    }]
check_with = [{
        'postal' : 'COLLISION_TRUE',
        'x': latitudes,
        'y': longitudes
    },{
        'postal' : 'COLLISION_FALSE',
        'x': latitudes + 50,
        'y': longitudes
    }]
test_single = PostMatcher(points)
test_single.renderAll()

collisions_test = test_single.check_collision(test_single.time_space[0], check_with)
# drawing test
test_single.draw(test_single.time_space[0], collisions_test['intersects'], fileName='map.html')
# sometimes image just won't show - experiment with file name: change it to random and try again
# if that don't work try it over and over again)
# error(f12->console): 
# Google Maps API error: MissingKeyMapError https://developers.google.com/maps/documentation/javascript/error-messages#missing-key-map-error_.jb @ js?libraries=visualization&sensor=true_or_false:34
# Out:
#         <iframe
#             width="90%"
#             height="500"
#             src="map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
collisions_test
# Out:
# {'intersects': [{'postal': 'COLLISION_TRUE',
#    'x': 59.87349399999999,
#    'y': 10.8140581}],
#  'nonintersect': [{'postal': 'COLLISION_FALSE',
#    'x': 109.873494,
#    'y': 10.8140581}],
#  'postal': 'TEST'}
